# %%
# !pip install cvlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 72.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for cvlib: filename=cvlib-0.2.7-py3-none-any.whl size=10046382 sha256=288e23d2d4b6cc3f088fc7ec7c381612b62b18e772e6fd24e392b0b229cf221e
#   Stored in directory: /root/.cache/pip/wheels/96/ad/4c/d80d4bf4143c154ab297e2384915c89aff43d77d1787b9a702
# ...
#   Created wheel for progressbar: filename=progressbar-2.5-py3-none-any.whl size=12080 sha256=e8f80c5d16804308e7baa2d3c6aeb82a9f4ae6f394d51cb7b48c4b0fb6bdc578
#   Stored in directory: /root/.cache/pip/wheels/d7/d9/89/a3f31c76ff6d51dc3b1575628f59afe59e4ceae3f2748cd7ad
# Successfully built cvlib progressbar
# ...

# %%
# !pip install opencv-contrib-python==3.4.13.47 -–force-reinstall
# Out:
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: -–

# %%
import cv2
cv2.__version__
# Out:
# '4.7.0'

# %%
from google.colab import files
data_to_load = files.upload()
# Out:
#      <input type="file" id="files-3a85c419-3474-4121-a2c5-a949d134e150" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3a85c419-3474-4121-a2c5-a949d134e150">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import cvlib as cv
from cvlib.object_detection import draw_bbox
from numpy.lib.polynomial import poly

#Read the image using imread and display imshow functions of OpenCV.

image = cv2.imread('originalimage.png')

plt.imshow(image)

plt.show()

#Detect common objects using detect_common_objects function of cv2

box, label, count = cv.detect_common_objects(image)

#Draw the box around the detected objects and assign labels

output = draw_bbox(image, box, label, count)

#Dispay the image

plt.imshow(output)

plt.show()

#Display the common objects like cars and truck detected

print('Number of cars in this image are ' +str(label.count("car")))

print('Number of trucks in this image are ' +str(label.count("truck")))
# Out:
#   0% |                                                                        |
# ...
# Number of cars in this image are 7
# Number of trucks in this image are 2
